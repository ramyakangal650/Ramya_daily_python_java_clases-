# %%
sentence = "Python programming language"
count = 0
for ch in sentence :
  if ch in "aeiou":
    count +=1
print("Total vowels is :",count)
# Out:
# Total vowels is : 8

# %%
sentence = "kle bk bca college in chikodi"
count = 0
for ch in sentence :
  if ch in "aeiou":
    count +=1
print("Total vowels is :",count)
# Out:
# Total vowels is : 9

# %%
base = 4
height = 5
triangle = 0.5 * base * height
print("Area of triangle is :",triangle)
# Out:
# Area of triangle is : 10.0

# %%
pie = 3.14
radius = 4
area = pie * radius * radius
print("Area of circle is :",area)
# Out:
# Area of circle is : 50.24

# %%
example = [5, 25, 35, 45, 10, 15]
lar = example[0]
for i in example :
  if i > lar :
    lar = i
print(lar,"is a largest number in this list")
# Out:
# 45 is a largest number in this list

# %%
numbers = [10, 25, 7, 99, 56]
lar = numbers[0]
for i in numbers :
  if i > lar :
    lar = i
print(lar,"is a largest number in this list")
# Out:
# 99 is a largest number in this list

# %%
sentence = "Bachelor of computer science first semister section c"
count = 0
for ch in sentence :
  if ch not in "a e i o u":
    count +=1
print("Total consonents is :",count)
# Out:
# Total consonents is : 29

# %%
  bikes = ["RX 100", "GT 650", "Ninja", "Spleder", "Bajaj","Pulsar", "NS 200", "M 80", "Unicorn"]
  for bike in bikes :
    if bike == "NS 200" :
      break
    print(bike)
# Out:
# RX 100
# GT 650
# Ninja
# Spleder
# Bajaj
# Pulsar

# %%
bikes = ["RX 100", "GT 650", "Ninja", "Spleder", "Bajaj","Pulsar", "NS 200", "M 80", "Unicorn"]
for bike in bikes :
    if bike == "XL Super" :
      break
    print(bike)
# Out:
# RX 100
# GT 650
# Ninja
# Spleder
# Bajaj
# Pulsar
# NS 200
# M 80
# Unicorn

# %%
colours = {"Purple", "Pink", "Black", "White", "Red", "Orange", "Levender", "Gray", "Yellow", "Maroon"}
for color in colours :
  if color == "Green" :
    break
  print(color)
# Out:
# Black
# Levender
# Yellow
# Gray
# Orange
# Maroon
# Pink
# White
# Red
# Purple

# %%
fruits = ["Apple", "Orange", "Mango", "Strawberry", "Dragon fruits", "greeps", "Banana", "Painapal", "Pappaya", "Water melon"]
for fruit in fruits :
  if fruit == "Greeps" :
    continue
  print(fruit)
# Out:
# Apple
# Orange
# Mango
# Strawberry
# Dragon fruits
# greeps
# Banana
# Painapal
# Pappaya
# Water melon

# %%
mobiles = {"Vivo","Redme","Oppo","Vivo","Vivo","Vivo","Oppo","IQee","Vivo","1 plus"}
for mobile in mobiles :
  if mobile == "Vivo" :
    continue
  print(mobile)
# Out:
# IQee
# Redme
# 1 plus
# Oppo

# %%
movies = ["KGF","Chhava","Bahubali","Saiyaara","RRR","Kalki","Kannadakagi onendonnu otti"]
for movie in movies :
  if movie == "RRR" :
    pass
  print(movie)
# Out:
# KGF
# Chhava
# Bahubali
# Saiyaara
# RRR
# Kalki
# Kannadakagi onendonnu otti

# %%
things = {"mobile","Laptop","Monitor","tab","Book","pen","Paper"}
for thing in things :
  if thing == "mobile" :
    continue
  print(thing)
# Out:
# Book
# Paper
# tab
# Monitor
# pen
# Laptop
